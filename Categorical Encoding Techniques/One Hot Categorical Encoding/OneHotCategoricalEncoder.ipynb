# %% [markdown]
# # Import Required Libraries

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %% [markdown]
# # Loading Data

# %%
data=pd.read_csv(r'C:\Users\Arun\DEPLOYMENT\Feature Engineering\Categorical Encoding Techniques\One Hot Categorical Encoding\houseprice1.csv',usecols=['Neighborhood', 'Exterior1st', 'Exterior2nd','SalePrice'])

# %%
data.head()
# Out:
#   Neighborhood Exterior1st Exterior2nd  SalePrice
# 0      CollgCr     VinylSd     VinylSd     208500
# 1      Veenker     MetalSd     MetalSd     181500
# 2      CollgCr     VinylSd     VinylSd     223500
# 3      Crawfor     Wd Sdng     Wd Shng     140000
# 4      NoRidge     VinylSd     VinylSd     250000

# %%
from sklearn.model_selection import train_test_split

# %% [markdown]
# # Dividing Data Set into Dependent and Independent Variables

# %%
x=data.iloc[:,:-1]
y=data.iloc[:,-1]

# %%
x.head()
# Out:
#   Neighborhood Exterior1st Exterior2nd
# 0      CollgCr     VinylSd     VinylSd
# 1      Veenker     MetalSd     MetalSd
# 2      CollgCr     VinylSd     VinylSd
# 3      Crawfor     Wd Sdng     Wd Shng
# 4      NoRidge     VinylSd     VinylSd

# %%
y.head()
# Out:
# 0    208500
# 1    181500
# 2    223500
# 3    140000
# 4    250000
# Name: SalePrice, dtype: int64

# %% [markdown]
# # Splitting Data into Training and Test Set

# %%
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.2,random_state=1)

# %% [markdown]
# # Implementing One Hot Encoding Using feature-engine

# %%
from feature_engine import categorical_encoders as ce

# %%
ohe=ce.OneHotCategoricalEncoder(top_categories=None,drop_last=True)

# %%
ohe.fit(x_train)
# Out:
# OneHotCategoricalEncoder(drop_last=True,
#                          variables=['Neighborhood', 'Exterior1st',
#                                     'Exterior2nd'])

# %%
x_train=ohe.transform(x_train)
x_test=ohe.transform(x_test)

# %%
x_train.head()
# Out:
#       Neighborhood_Edwards  Neighborhood_OldTown  Neighborhood_CollgCr  \
# 921                      1                     0                     0
# 520                      0                     1                     0
# 401                      0                     0                     1
# 280                      0                     0                     0
# 1401                     0                     0                     0
#
#       Neighborhood_SawyerW  Neighborhood_Gilbert  Neighborhood_NAmes  \
# 921                      0                     0                   0
# 520                      0                     0                   0
# 401                      0                     0                   0
# 280                      1                     0                   0
# 1401                     0                     1                   0
#
#       Neighborhood_Mitchel  Neighborhood_NWAmes  Neighborhood_Somerst  \
# ...

# %%
x_test.head()
# Out:
#       Neighborhood_Edwards  Neighborhood_OldTown  Neighborhood_CollgCr  \
# 258                      0                     0                     1
# 267                      0                     0                     0
# 288                      0                     0                     0
# 649                      0                     0                     0
# 1233                     0                     0                     0
#
#       Neighborhood_SawyerW  Neighborhood_Gilbert  Neighborhood_NAmes  \
# 258                      0                     0                   0
# 267                      0                     0                   0
# 288                      0                     0                   0
# 649                      0                     0                   0
# 1233                     0                     0                   1
#
#       Neighborhood_Mitchel  Neighborhood_NWAmes  Neighborhood_Somerst  \
# ...

# %%
ohe.variables
# Out:
# ['Neighborhood', 'Exterior1st', 'Exterior2nd']

# %%
x_train1,x_test1,y_train1,y_test1=train_test_split(x,y,test_size=0.2,random_state=1)

# %% [markdown]
# # Implementing One Hot Encoding Only for Particular Variable

# %%
ohe1=ce.OneHotCategoricalEncoder(top_categories=None,drop_last=True,variables=['Neighborhood'])

# %%
ohe1.fit(x_train1)
# Out:
# OneHotCategoricalEncoder(drop_last=True, variables=['Neighborhood'])

# %%
x_train1=ohe1.transform(x_train1)
x_test1=ohe1.transform(x_test1)

# %%
x_train1.head()
# Out:
#      Exterior1st Exterior2nd  Neighborhood_Edwards  Neighborhood_OldTown  \
# 921      MetalSd     MetalSd                     1                     0
# 520      MetalSd     MetalSd                     0                     1
# 401      VinylSd     VinylSd                     0                     0
# 280      Plywood     Plywood                     0                     0
# 1401     VinylSd     VinylSd                     0                     0
#
#       Neighborhood_CollgCr  Neighborhood_SawyerW  Neighborhood_Gilbert  \
# 921                      0                     0                     0
# 520                      0                     0                     0
# 401                      1                     0                     0
# 280                      0                     1                     0
# 1401                     0                     0                     1
#
#       Neighborhood_NAmes  Neighborhood_Mitchel  Neighborhood_NWAmes  ...  \
# ...

# %%
x_test1.head()
# Out:
#      Exterior1st Exterior2nd  Neighborhood_Edwards  Neighborhood_OldTown  \
# 258      VinylSd     VinylSd                     0                     0
# 267      Wd Sdng     Wd Sdng                     0                     0
# 288      MetalSd     MetalSd                     0                     0
# 649      CemntBd     CmentBd                     0                     0
# 1233     Plywood     Plywood                     0                     0
#
#       Neighborhood_CollgCr  Neighborhood_SawyerW  Neighborhood_Gilbert  \
# 258                      1                     0                     0
# 267                      0                     0                     0
# 288                      0                     0                     0
# 649                      0                     0                     0
# 1233                     0                     0                     0
#
#       Neighborhood_NAmes  Neighborhood_Mitchel  Neighborhood_NWAmes  ...  \
# ...

# %%
ohe1.variables
# Out:
# ['Neighborhood']

# %%
x_train2,x_test2,y_train2,y_test2=train_test_split(x,y,test_size=0.2,random_state=1)

# %% [markdown]
# # Implementing One Hot Encoding For Most Frequent Categories

# %%
ohe2=ce.OneHotCategoricalEncoder(top_categories=10)

# %%
ohe2.fit(x_train2)
# Out:
# OneHotCategoricalEncoder(top_categories=10,
#                          variables=['Neighborhood', 'Exterior1st',
#                                     'Exterior2nd'])

# %%
x_train2=ohe2.transform(x_train2)
x_test2=ohe2.transform(x_test2)

# %%
x_train2.head()
# Out:
#       Neighborhood_NAmes  Neighborhood_CollgCr  Neighborhood_OldTown  \
# 921                    0                     0                     0
# 520                    0                     0                     1
# 401                    0                     1                     0
# 280                    0                     0                     0
# 1401                   0                     0                     0
#
#       Neighborhood_Edwards  Neighborhood_Somerst  Neighborhood_NridgHt  \
# 921                      1                     0                     0
# 520                      0                     0                     0
# 401                      0                     0                     0
# 280                      0                     0                     0
# 1401                     0                     0                     0
#
#       Neighborhood_Gilbert  Neighborhood_NWAmes  Neighborhood_Sawyer  \
# ...

# %%
x_test2.head()
# Out:
#       Neighborhood_NAmes  Neighborhood_CollgCr  Neighborhood_OldTown  \
# 258                    0                     1                     0
# 267                    0                     0                     0
# 288                    0                     0                     0
# 649                    0                     0                     0
# 1233                   1                     0                     0
#
#       Neighborhood_Edwards  Neighborhood_Somerst  Neighborhood_NridgHt  \
# 258                      0                     0                     0
# 267                      0                     0                     0
# 288                      0                     0                     0
# 649                      0                     0                     0
# 1233                     0                     0                     0
#
#       Neighborhood_Gilbert  Neighborhood_NWAmes  Neighborhood_Sawyer  \
# ...

# %%
ohe2.encoder_dict_
# Out:
# {'Neighborhood': ['NAmes',
#   'CollgCr',
#   'OldTown',
#   'Edwards',
#   'Somerst',
#   'NridgHt',
#   'Gilbert',
#   'NWAmes',
#   'Sawyer',
#   'BrkSide'],
#  'Exterior1st': ['VinylSd',
#   'MetalSd',
#   'HdBoard',
#   'Wd Sdng',
#   'Plywood',
#   'CemntBd',
#   'BrkFace',
#   'Stucco',
#   'WdShing',
#   'AsbShng'],
#  'Exterior2nd': ['VinylSd',
#   'MetalSd',
#   'HdBoard',
#   'Wd Sdng',
#   'Plywood',
#   'CmentBd',
#   'Wd Shng',
#   'Stucco',
#   'BrkFace',
#   'AsbShng']}
